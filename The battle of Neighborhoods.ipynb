# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohamad-Alshalabi/Coursera_Capstone/blob/master/The%20battle%20of%20Neighborhoods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**THE BATTLE OF NEIGHBORHOODS**

# %% [markdown]
# #**Introduction**
#
#
#
# Stockholm is the capital and most populous urban area of Sweden as well as in Scandinavia. Around 1 million people live in the municipality, approximately 1.6 million in the urban area, and 2.4 million in the metropolitan area. The city stretches across fourteen islands and it's one of the five fastest-growing cities in Europe.
#
#
# Geographically, Stockholm city area only covers 188 squared kilometers; the area stretches to 6,519 squared kilometers for the metropolitan area. The disparity between the city center's density and the metropolitan area is more than ten folds, where the density within the city center is 5200 per sqr/km, the density in the metropolitan area is only 370 per sqr/km.
# There are more than 3000 restaurants in Stockholm. The biggest food retailers in Sweden collectively have around 460 stores in Stockholm.

# %% [markdown]
# ##**Problem**
#
#
# The food supply in Stockholm metropolitan area concentrates mainly within the center, while the peripheries have less coverage. Opening a new food venue might be more profitable if the new establishments locate in areas with higher food demand. To tackle this problem we need to estimate the food demand in each neighborhood.
# 1.	Define Stockholm's neighborhoods
# 2.	Estimate the food demand in each neighborhood

# %% [markdown]
# #**Target market**
#
#
# This study can benefit both food retailers and new investors in the food and beverage market in Stockholm, pointing out the regions with the least food coverage can open the path for various investment opportunities.

# %% [markdown]
# #**Data**
#
# **The data is obtained from various sources. The issue of data availability is overcome by creating our own sources.**
#
# To answer the question of which neighborhood in Stockholm has the least coverage of food venues, we should look into two main variables: the number of venues in each neighborhood. The Second variable is concerning the number of inhabitants in the neighborhood.
# In the list below I include the three source of data used in this study.
# 1. The name and the postal code for each neighborhood collected and scrapped from the following website: https://worldpostalcode.com
# 2. The Latitude, the Longitude and the Population for each neighborhood in stockholm manually collected and gathered in one CSV file.
# 3. Name, location, latitude, longitude for each food venue in the neighborhoods collected from https://api.foursquare.com website.

# %%
# !pip install geocoder
# !pip install folium
import numpy as np 
import pandas as pd 
import geocoder 
import requests 
from requests import get 
from bs4 import BeautifulSoup 
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium 
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize
print("Importing is done")
# Out:
# Requirement already satisfied: geocoder in /usr/local/lib/python3.6/dist-packages (1.38.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from geocoder) (1.15.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from geocoder) (0.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from geocoder) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from geocoder) (2.23.0)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.6/dist-packages (from geocoder) (0.1.6)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (1.24.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: folium in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from folium) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from folium) (1.15.0)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from folium) (0.4.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from folium) (2.23.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->folium) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2020.12.5)
# Importing is done

# %%
url = "https://worldpostalcode.com/sweden/stockholm/"
response = get(url)
html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
Stockholm_containers = html_soup.find_all('div', class_ = 'container')
print(type(Stockholm_containers))
print(len(Stockholm_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 64

# %%
names = []
for container in Stockholm_containers:
    if container.find('div') is not None:
        name = container.div.text
    names.append(name)

# %%
Stockholm_codes = html_soup.find_all( class_ = 'code')
codes = []
for code in Stockholm_codes :
    i = Stockholm_codes.index(code)
    code = str(code)
    code = code.replace('<div class="code"><span>', '')
    code = code.replace('</span></div>', '')    
    code = code.split('</span> <span>') 
    codes.append(code)

# %%
data = {'Neighborhood': names, 'Postal_Code': codes}
Data= pd.DataFrame(data= data, columns= ['Neighborhood','Postal_Code'])

# %%
Stockholm_data = pd.read_csv("https://raw.githubusercontent.com/Mohamad-Alshalabi/Coursera_Capstone/master/Book2.csv")

Stockholm_data.head()
# Out:
#   Neighborhood  Latitude  Longitude  Population
# 0   Akersberga   59.4803    18.3108        28033
# 1         Alta   59.2555    18.1781         9989
# 2       Alvsjo   59.2745    18.0051         1530
# 3        Arsta   59.2986    18.0459        16807
# 4  Bagarmossen   59.2744    18.1338        10915

# %%
Stockholm_geo_data = pd.merge(Stockholm_data, Data, on='Neighborhood')
Stockholm_geo_data.head()
# Out:
#   Neighborhood  ...                                        Postal_Code
# 0   Akersberga  ...                                           [184 20]
# 1         Alta  ...                                           [138 20]
# 2       Alvsjo  ...  [125 00, 125 58, 125 52, 125 53, 125 54, 125 5...
# 3        Arsta  ...  [120 02, 120 52, 120 59, 120 58, 120 57, 120 5...
# 4  Bagarmossen  ...  [128 04, 128 05, 128 41, 128 42, 128 43, 128 4...
#
# [5 rows x 5 columns]

# %%
print('The dataframe has {} neighborhoods.'.format( len(Stockholm_geo_data['Neighborhood'].unique())))
# Out:
# The dataframe has 64 neighborhoods.

# %%
address = 'Stockholm Sweden'
geolocator = Nominatim(user_agent="stock_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Stockholm are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Stockholm are 59.3251172, 18.0710935.

# %%
map_Stockholm = folium.Map(location=[latitude,longitude], zoom_start= 10)
for lat, lng, label in zip(Stockholm_geo_data['Latitude'], Stockholm_geo_data['Longitude'], Stockholm_geo_data['Neighborhood']):
    label = folium.Popup(label, parse_html= True)
    folium.CircleMarker(
        [lat,lng],
        radius=6,
        popup= label, 
        color= 'blue',
        fill= True,
        fill_color= 'FFFF5c', 
        fill_opacity= 0.7
        ).add_to(map_Stockholm)

map_Stockholm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_814169c4bdce4eda947672b96ab68d67%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_814169c4bdce4eda947672b96ab68d67%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_814169c4bdce4eda947672b96ab68d67%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_814169c4bdce4eda947672b96ab68d67%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B59.3251172%2C%2018.0710935%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_4d9bee0332934c61adc1a614ff4d9854%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%2 ...

# %%
CLIENT_ID = 'CAH33GB3T5AA33ZLAPKRSPMN0HPJAF0CRI1ES31CMFKIMRT0' 
CLIENT_SECRET = 'Q1LRHG2SDJMSACGJGKA1K2CMDWGMPJQSN05CWAMEOOEFH0YL' 
VERSION = '20210217'

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
       
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            100)
            
       
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
      
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
Stockholm_venues = getNearbyVenues(names=Stockholm_geo_data['Neighborhood'],
                                   latitudes=Stockholm_geo_data['Latitude'],
                                   longitudes=Stockholm_geo_data['Longitude'],
                                  )
# Out:
# Akersberga
# Alta
# Alvsjo
# Arsta
# Bagarmossen
# Bandhagen
# Bro
# Bromma
# Danderyd
# Ekero
# Enskede
# Enskede Gard
# Enskededalen
# Farsta
# Gustavsberg
# Hagersten
# Hallstavik
# Handen
# Haninge
# Hasselby
# Huddinge
# Jarfalla
# Jarna
# Johanneshov
# Kista
# Kungsangen
# Lidingo
# Marsta
# Nacka
# Norrtalje
# Norsborg
# Nykvarn
# Nynashamn
# Osmo
# Rimbo
# Ronninge
# Rosersberg
# Saltsjo-Boo
# Saltsjobaden
# Sigtuna
# Skarholmen
# Skarpnack
# Skogas
# Skondal
# Sodertalje
# Sollentuna
# Solna
# Spanga
# Stockholm
# Stockholm-Arlanda
# Stockholm-Globen
# Sundbyberg
# Taby
# Tomteboda
# Tullinge
# Tumba
# Tyreso
# Upplands Vasby
# Vallentuna
# Vallingby
# Varby
# Varmdo
# Vasterhaninge
# Vaxholm

# %%
Stockholm_venues.groupby('Neighborhood').count()
# Out:
#                Neighborhood Latitude  ...  Venue Category
# Neighborhood                          ...
# Akersberga                         4  ...               4
# Alta                               7  ...               7
# Alvsjo                            13  ...              13
# Arsta                             13  ...              13
# Bagarmossen                        9  ...               9
# ...                              ...  ...             ...
# Vallentuna                         7  ...               7
# Vallingby                         12  ...              12
# Varby                              4  ...               4
# Vasterhaninge                      4  ...               4
# Vaxholm                            4  ...               4
#
# [63 rows x 6 columns]

# %%
Stockholm_venues.groupby('Neighborhood').count()
# Out:
#                Neighborhood Latitude  ...  Venue Category
# Neighborhood                          ...
# Akersberga                         4  ...               4
# Alta                               7  ...               7
# Alvsjo                            13  ...              13
# Arsta                             13  ...              13
# Bagarmossen                        9  ...               9
# ...                              ...  ...             ...
# Vallentuna                         7  ...               7
# Vallingby                         12  ...              12
# Varby                              4  ...               4
# Vasterhaninge                      4  ...               4
# Vaxholm                            4  ...               4
#
# [63 rows x 6 columns]

# %%
print('There are {} uniques categories.'.format(len(Stockholm_venues['Venue Category'].unique())))
# Out:
# There are 148 uniques categories.

# %%
Stockholm_onehot = pd.get_dummies(Stockholm_venues[['Venue Category']], prefix="", prefix_sep="")
Stockholm_onehot['Neighborhood'] = Stockholm_venues['Neighborhood'] 
fixed_columns = [Stockholm_onehot.columns[-1]] + list(Stockholm_onehot.columns[:-1])
Stockholm_onehot = Stockholm_onehot[fixed_columns]
Stockholm_onehot.head()
# Out:
#   Neighborhood  Airport  ...  Turkish Restaurant  Vietnamese Restaurant
# 0   Akersberga        0  ...                   0                      0
# 1   Akersberga        0  ...                   0                      0
# 2   Akersberga        0  ...                   0                      0
# 3   Akersberga        0  ...                   0                      0
# 4         Alta        0  ...                   0                      0
#
# [5 rows x 149 columns]

# %%
Stockholm_onehot.shape
# Out:
# (650, 149)

# %%
Stockholm_grouped = Stockholm_onehot.groupby('Neighborhood').mean().reset_index()
Stockholm_grouped
# Out:
#      Neighborhood  Airport  ...  Turkish Restaurant  Vietnamese Restaurant
# 0      Akersberga      0.0  ...                 0.0                    0.0
# 1            Alta      0.0  ...                 0.0                    0.0
# 2          Alvsjo      0.0  ...                 0.0                    0.0
# 3           Arsta      0.0  ...                 0.0                    0.0
# 4     Bagarmossen      0.0  ...                 0.0                    0.0
# ..            ...      ...  ...                 ...                    ...
# 58     Vallentuna      0.0  ...                 0.0                    0.0
# 59      Vallingby      0.0  ...                 0.0                    0.0
# 60          Varby      0.0  ...                 0.0                    0.0
# 61  Vasterhaninge      0.0  ...                 0.0                    0.0
# 62        Vaxholm      0.0  ...                 0.0                    0.0
#
# [63 rows x 149 columns]

# %%
num_top_venues = 5

for hood in Stockholm_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = Stockholm_grouped[Stockholm_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Akersberga----
#                         venue  freq
# 0                Burger Joint  0.25
# 1        Gym / Fitness Center  0.25
# 2                 Pizza Place  0.25
# 3  Construction & Landscaping  0.25
# 4                Optical Shop  0.00
#
#
# ----Alta----
#                   venue  freq
# 0          Hockey Arena  0.14
# 1  Arts & Entertainment  0.14
# 2          Soccer Field  0.14
# 3                  Café  0.14
# 4         Shopping Mall  0.14
#
#
# ----Alvsjo----
#                   venue  freq
# 0                 Hotel  0.15
# 1           Supermarket  0.08
# 2  Gym / Fitness Center  0.08
# 3          Soccer Field  0.08
# 4              Gym Pool  0.08
#
#
# ----Arsta----
#                      venue  freq
# 0                    Plaza  0.08
# 1               Restaurant  0.08
# 2                     Café  0.08
# 3                   Forest  0.08
# 4  Scandinavian Restaurant  0.08
#
#
# ----Bagarmossen----
#                   venue  freq
# 0                   Pub  0.11
# 1           Pizza Place  0.11
# 2  Fast Food Restaurant  0.11
# 3                 Plaza  0.11
# 4           Supermarket  0.11
#
#
# ----Bandhagen----
#                       venue  freq
# 0               Bus Station  0.17
# 1               Pizza Place  0.17
# 2  Mediterranean Restaurant  0.08
# 3                      Café  0.08
# 4             Grocery Store  0.08
#
#
# ----Bro----
#            venue  freq
# 0    Pizza Place  0.25
# 1  Train Station  0.25
# 2       Gym Pool  0.25
# 3  Grocery Store  0.25
# 4        Airport  0.00
#
#
# ----Bromma----
#                 venue  freq
# 0         Supermarket  0.18
# 1    Sushi Restaurant  0.18
# 2                 Pub  0.09
# 3        Liquor Store  0.09
# 4  Chinese Restaurant  0.09
#
#
# ----Danderyd----
#            venue  freq
# 0           Pool   0.5
# 1    Pizza Place   0.5
# 2   Optical Shop   0.0
# 3  Moving Target   0.0
# 4      Multiplex   0.0
#
#
# ----Ekero----
#                   venue  freq
# 0           Pizza Place  0.25
# 1  Gym / Fitness Center  0.25
# 2     Convenience Store  0.25
# 3               Stadium  0.25
# 4               Airport  0.00
#
#
# ----Enskede----
#                venue  freq
# 0        Bus Station  0.25
# 1    Automotive Shop  0.25
# 2        Art Gallery  0.25
# 3  Food & Drink Shop  0.25
# 4      Moving Target  0.00
#
#
# ----Enskede Gard----
#                 venue  freq
# 0          Restaurant  0.33
# 1             Stables  0.17
# 2  Light Rail Station  0.17
# 3              Bakery  0.17
# 4       Metro Station  0.17
#
#
# ----Enskededalen----
#                   venue  freq
# 0            Playground   0.2
# 1     Indian Restaurant   0.2
# 2      Asian Restaurant   0.2
# 3  Fast Food Restaurant   0.2
# 4         Grocery Store   0.2
#
#
# ----Farsta----
#              venue  freq
# 0    Grocery Store  0.21
# 1            Plaza  0.14
# 2      Pizza Place  0.14
# 3  Thai Restaurant  0.07
# 4             Farm  0.07
#
#
# ----Gustavsberg----
#                venue  freq
# 0               Lake   1.0
# 1            Airport   0.0
# 2  Outdoor Sculpture   0.0
# 3      Moving Target   0.0
# 4          Multiplex   0.0
#
#
# ----Hagersten----
#            venue  freq
# 0         Forest   1.0
# 1        Airport   0.0
# 2  Movie Theater   0.0
# 3      Multiplex   0.0
# 4    Music Venue   0.0
#
#
# ----Hallstavik----
#                         venue  freq
# 0               Grocery Store   0.4
# 1                 Supermarket   0.2
# 2  Construction & Landscaping   0.2
# 3                 Flower Shop   0.2
# 4                     Airport   0.0
#
#
# ----Handen----
#                        venue  freq
# 0             Clothing Store  0.25
# 1                Bus Station  0.12
# 2                      Hotel  0.12
# 3              Shopping Mall  0.12
# 4  Middle Eastern Restaurant  0.12
#
#
# ----Haninge----
#                   venue  freq
# 0  Fast Food Restaurant  0.14
# 1           Supermarket  0.09
# 2            Shoe Store  0.09
# 3      Department Store  0.09
# 4           Coffee Shop  0.05
#
#
# ----Hasselby----
#               venue  freq
# 0  Business Service   0.1
# 1     Metro Station   0.1
# 2       Event Space   0.1
# 3              Pool   0.1
# 4        Playground   0.1
#
#
# ----Huddinge----
#                venue  freq
# 0               Lake   1.0
# 1            Airport   0.0
# 2  Outdoor Sculpture   0.0
# 3      Moving Target   0.0
# 4          Multiplex   0.0
#
#
# ----Jarfalla----
#            venue  freq
# 0   Burger Joint   1.0
# 1        Airport   0.0
# 2  Moving Target   0.0
# 3      Multiplex   0.0
# 4    Music Venue   0.0
#
#
# ----Jarna----
#              venue  freq
# 0      Music Venue   0.2
# 1      Supermarket   0.2
# 2           Bakery   0.2
# 3  Thai Restaurant   0.2
# 4      Hockey Rink   0.2
#
#
# ----Johanneshov----
#                   venue  freq
# 0            Restaurant  0.10
# 1     Convenience Store  0.10
# 2  Gym / Fitness Center  0.10
# 3         Metro Station  0.05
# 4           Pizza Place  0.05
#
#
# ----Kista----
#                        venue  freq
# 0       Gym / Fitness Center  0.08
# 1  Middle Eastern Restaurant  0.07
# 2                 Restaurant  0.07
# 3                Coffee Shop  0.07
# 4           Asian Restaurant  0.07
#
#
# ----Kungsangen----
#            venue  freq
# 0  Train Station  0.17
# 1       Pharmacy  0.17
# 2           Café  0.17
# 3    Supermarket  0.17
# 4   Liquor Store  0.17
#
#
# ----Lidingo----
#               venue  freq
# 0       Pizza Place  0.25
# 1   Thai Restaurant  0.25
# 2  Sushi Restaurant  0.25
# 3      Soccer Field  0.25
# 4            Palace  0.00
#
#
# ----Marsta----
#                  venue  freq
# 0          Supermarket  0.27
# 1  Japanese Restaurant  0.07
# 2          Pizza Place  0.07
# 3  American Restaurant  0.07
# 4             Pharmacy  0.07
#
#
# ----Nacka----
#                  venue  freq
# 0             Ski Area   1.0
# 1              Airport   0.0
# 2  Monument / Landmark   0.0
# 3        Moving Target   0.0
# 4            Multiplex   0.0
#
#
# ----Norrtalje----
#           venue  freq
# 0          Café   0.4
# 1  Burger Joint   0.1
# 2    Restaurant   0.1
# 3         River   0.1
# 4  Liquor Store   0.1
#
#
# ----Norsborg----
#                venue  freq
# 0        Bus Station  0.22
# 1  Convenience Store  0.22
# 2      Shopping Mall  0.11
# 3            Theater  0.11
# 4        Supermarket  0.11
#
#
# ----Nykvarn----
#                venue  freq
# 0  Food & Drink Shop   0.2
# 1        Pizza Place   0.2
# 2      Train Station   0.2
# 3        Flower Shop   0.2
# 4      Grocery Store   0.2
#
#
# ----Nynashamn----
#                      venue  freq
# 0                     Café  0.22
# 1  Scandinavian Restaurant  0.17
# 2           Ice Cream Shop  0.06
# 3          Harbor / Marina  0.06
# 4             Burger Joint  0.06
#
#
# ----Osmo----
#               venue  freq
# 0       Bus Station   0.4
# 1      Burger Joint   0.2
# 2     Grocery Store   0.2
# 3  Department Store   0.2
# 4      Optical Shop   0.0
#
#
# ----Rimbo----
#                venue  freq
# 0               Café  0.50
# 1       Liquor Store  0.25
# 2       Hockey Arena  0.25
# 3            Airport  0.00
# 4  Outdoor Sculpture  0.00
#
#
# ----Ronninge----
#            venue  freq
# 0          Plaza  0.17
# 1    Pizza Place  0.17
# 2  Grocery Store  0.17
# 3            Bar  0.17
# 4    Bus Station  0.17
#
#
# ----Rosersberg----
#                         venue  freq
# 0  Construction & Landscaping   1.0
# 1                     Airport   0.0
# 2           Outdoor Sculpture   0.0
# 3                   Multiplex   0.0
# 4                 Music Venue   0.0
#
#
# ----Saltsjo-Boo----
#            venue  freq
# 0       Bus Stop   1.0
# 1        Airport   0.0
# 2  Movie Theater   0.0
# 3      Multiplex   0.0
# 4    Music Venue   0.0
#
#
# ----Saltsjobaden----
#                 venue  freq
# 0     Harbor / Marina  0.38
# 1                Café  0.12
# 2          Restaurant  0.12
# 3  Light Rail Station  0.12
# 4    Asian Restaurant  0.12
#
#
# ----Sigtuna----
#                      venue  freq
# 0                     Café  0.36
# 1  Scandinavian Restaurant  0.18
# 2            Historic Site  0.09
# 3            Grocery Store  0.09
# 4                    Plaza  0.09
#
#
# ----Skarholmen----
#                        venue  freq
# 0       Fast Food Restaurant  0.12
# 1  Middle Eastern Restaurant  0.06
# 2                      Plaza  0.06
# 3          Food & Drink Shop  0.06
# 4               Optical Shop  0.06
#
#
# ----Skarpnack----
#                  venue  freq
# 0          Pizza Place   0.4
# 1  Japanese Restaurant   0.2
# 2          Supermarket   0.2
# 3        Garden Center   0.2
# 4         Noodle House   0.0
#
#
# ----Skogas----
#            venue  freq
# 0  Grocery Store   0.3
# 1   Liquor Store   0.1
# 2       Fountain   0.1
# 3    Coffee Shop   0.1
# 4    Bus Station   0.1
#
#
# ----Skondal----
#              venue  freq
# 0      Bus Station   0.2
# 1             Café   0.2
# 2            Beach   0.2
# 3             Park   0.2
# 4  Assisted Living   0.2
#
#
# ----Sodertalje----
#                      venue  freq
# 0       Italian Restaurant  0.15
# 1                     Café  0.15
# 2        Convenience Store  0.08
# 3  Scandinavian Restaurant  0.08
# 4      American Restaurant  0.08
#
#
# ----Sollentuna----
#                     venue  freq
# 0            Burger Joint  0.33
# 1  Furniture / Home Store  0.33
# 2      Athletics & Sports  0.33
# 3             Pizza Place  0.00
# 4                Pharmacy  0.00
#
#
# ----Solna----
#                   venue  freq
# 0            Restaurant  0.08
# 1        Clothing Store  0.08
# 2                  Café  0.08
# 3  Fast Food Restaurant  0.04
# 4          Burger Joint  0.04
#
#
# ----Spanga----
#                venue  freq
# 0        Pizza Place  0.07
# 1                Pub  0.07
# 2      Grocery Store  0.07
# 3            Butcher  0.07
# 4  Convenience Store  0.07
#
#
# ----Stockholm----
#                      venue  freq
# 0                    Hotel  0.16
# 1  Scandinavian Restaurant  0.11
# 2      Monument / Landmark  0.05
# 3                   Bakery  0.05
# 4         Department Store  0.05
#
#
# ----Stockholm-Arlanda----
#                 venue  freq
# 0               Hotel  0.10
# 1     Airport Service  0.10
# 2                Café  0.07
# 3  Italian Restaurant  0.07
# 4      Airport Lounge  0.07
#
#
# ----Stockholm-Globen----
#                   venue  freq
# 0             Nightclub  0.09
# 1  Gym / Fitness Center  0.09
# 2          Hockey Arena  0.09
# 3         Go Kart Track  0.04
# 4    Chinese Restaurant  0.04
#
#
# ----Sundbyberg----
#                    venue  freq
# 0             Playground   0.2
# 1                  Trail   0.2
# 2            Supermarket   0.2
# 3  Outdoors & Recreation   0.2
# 4     Athletics & Sports   0.2
#
#
# ----Taby----
#                     venue  freq
# 0  Furniture / Home Store  0.08
# 1             Coffee Shop  0.08
# 2       Electronics Store  0.08
# 3           Grocery Store  0.05
# 4               Juice Bar  0.05
#
#
# ----Tomteboda----
#            venue  freq
# 0           Café   1.0
# 1        Airport   0.0
# 2  Movie Theater   0.0
# 3      Multiplex   0.0
# 4    Music Venue   0.0
#
#
# ----Tullinge----
#               venue  freq
# 0       Pizza Place  0.50
# 1        Playground  0.25
# 2  Sushi Restaurant  0.25
# 3      Noodle House  0.00
# 4     Movie Theater  0.00
#
#
# ----Tumba----
#                venue  freq
# 0      Train Station  0.25
# 1  Convenience Store  0.25
# 2         Restaurant  0.25
# 3       Liquor Store  0.25
# 4            Airport  0.00
#
#
# ----Tyreso----
#                 venue  freq
# 0  Italian Restaurant  0.25
# 1                Café  0.25
# 2    Asian Restaurant  0.25
# 3       Grocery Store  0.25
# 4             Airport  0.00
#
#
# ----Upplands Vasby----
#            venue  freq
# 0    Bus Station   0.5
# 1       Bus Stop   0.5
# 2   Optical Shop   0.0
# 3  Moving Target   0.0
# 4      Multiplex   0.0
#
#
# ----Vallentuna----
#                 venue  freq
# 0  Italian Restaurant  0.14
# 1                 Gym  0.14
# 2          Public Art  0.14
# 3               Plaza  0.14
# 4  Light Rail Station  0.14
#
#
# ----Vallingby----
#                   venue  freq
# 0  Gym / Fitness Center  0.17
# 1           Supermarket  0.08
# 2                  Park  0.08
# 3         Moving Target  0.08
# 4                  Café  0.08
#
#
# ----Varby----
#            venue  freq
# 0  Grocery Store  0.25
# 1    Pizza Place  0.25
# 2       Gym Pool  0.25
# 3  Metro Station  0.25
# 4      Nightclub  0.00
#
#
# ----Vasterhaninge----
#            venue  freq
# 0    Bus Station  0.25
# 1  Grocery Store  0.25
# 2  Train Station  0.25
# 3    Supermarket  0.25
# 4   Noodle House  0.00
#
#
# ----Vaxholm----
#                venue  freq
# 0      Grocery Store  0.25
# 1  Convenience Store  0.25
# 2       Skating Rink  0.25
# 3       Soccer Field  0.25
# 4               Park  0.00

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10
indicators = ['st', 'nd', 'rd']
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Stockholm_grouped['Neighborhood']

for ind in np.arange(Stockholm_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Stockholm_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(20)
# Out:
#     Neighborhood  ...  10th Most Common Venue
# 0     Akersberga  ...              Food Court
# 1           Alta  ...             Event Space
# 2         Alvsjo  ...                Gym Pool
# 3          Arsta  ...           Grocery Store
# 4    Bagarmossen  ...   Vietnamese Restaurant
# 5      Bandhagen  ...              Hobby Shop
# 6            Bro  ...       Food & Drink Shop
# 7         Bromma  ...                    Farm
# 8       Danderyd  ...             Flower Shop
# 9          Ekero  ...              Food Court
# 10       Enskede  ...                Fountain
# 11  Enskede Gard  ...              Food Truck
# 12  Enskededalen  ...       Electronics Store
# 13        Farsta  ...                  Bakery
# 14   Gustavsberg  ...       Food & Drink Shop
# 15     Hagersten  ...             Flower Shop
# 16    Hallstavik  ...              Food Court
# 17        Handen  ...  Furniture / Home Store
# 18       Haninge  ...    Gym / Fitness Center
# 19      Hasselby  ...           Moving Target
#
# [20 rows x 11 columns]

# %%
Stockholm_grouped_clustring= Stockholm_grouped.drop('Neighborhood', 1)
Sum_of_squared_distances = []
K = range(1,40)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(Stockholm_grouped_clustring)
    Sum_of_squared_distances.append(km.inertia_)

# %%
import matplotlib.pyplot as plt
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
kclusters = 8
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Stockholm_grouped_clustring)
kmeans.labels_[0:10]
# Out:
# array([6, 6, 6, 6, 6, 6, 1, 6, 6, 6], dtype=int32)

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

Stockholm_merged = Stockholm_geo_data

Stockholm_merged = Stockholm_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
Stockholm_merged.drop([16], inplace=True)
Stockholm_merged.reset_index()

Stockholm_merged
# Out:
#      Neighborhood  Latitude  ...  9th Most Common Venue  10th Most Common Venue
# 0      Akersberga   59.4803  ...             Food Truck              Food Court
# 1            Alta   59.2555  ...              Hotel Bar             Event Space
# 2          Alvsjo   59.2745  ...                 Bakery                Gym Pool
# 3           Arsta   59.2986  ...       Greek Restaurant           Grocery Store
# 4     Bagarmossen   59.2744  ...       Sushi Restaurant   Vietnamese Restaurant
# ..            ...       ...  ...                    ...                     ...
# 59      Vallingby   59.3671  ...       Business Service                 Theater
# 60          Varby   59.2635  ...             Food Truck              Food Court
# 61         Varmdo   59.2846  ...                    NaN                     NaN
# 62  Vasterhaninge   59.1216  ...                 Forest              Food Truck
# 63        Vaxholm   59.4033  ...             Food Truck              Food Court
#
# [63 rows x 16 columns]

# %%
Stockholm_merged.loc[Stockholm_merged['Cluster Labels'] == 0, Stockholm_merged.columns[[0] + list(range(5, Stockholm_merged.shape[1]))]]
# Out:
#    Neighborhood  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 36   Rosersberg             0.0  ...            Food Court            Flower Shop
#
# [1 rows x 12 columns]

# %%
Stockholm_merged.loc[Stockholm_merged['Cluster Labels'] == 1, Stockholm_merged.columns[[0] + list(range(5, Stockholm_merged.shape[1]))]]
# Out:
#      Neighborhood  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 6             Bro             1.0  ...            Food Court      Food & Drink Shop
# 13         Farsta             1.0  ...        Shopping Plaza                 Bakery
# 25     Kungsangen             1.0  ...              Fountain                 Forest
# 31        Nykvarn             1.0  ...            Food Truck             Food Court
# 33           Osmo             1.0  ...              Fountain                 Forest
# 35       Ronninge             1.0  ...                Forest             Food Truck
# 42         Skogas             1.0  ...                  Farm         Farmers Market
# 60          Varby             1.0  ...            Food Truck             Food Court
# 62  Vasterhaninge             1.0  ...                Forest             Food Truck
# 63        Vaxholm             1.0  ...            Food Truck             Food Court
#
# [10 rows x 12 columns]

# %%
Stockholm_merged.loc[Stockholm_merged['Cluster Labels'] == 2, Stockholm_merged.columns[[0] + list(range(5, Stockholm_merged.shape[1]))]]
# Out:
#    Neighborhood  Cluster Labels  ...   9th Most Common Venue 10th Most Common Venue
# 29    Norrtalje             2.0  ...  Furniture / Home Store                 Forest
# 32    Nynashamn             2.0  ...            Liquor Store           Burger Joint
# 34        Rimbo             2.0  ...              Food Court      Food & Drink Shop
# 39      Sigtuna             2.0  ...            Hockey Arena      Electronics Store
# 53    Tomteboda             2.0  ...              Food Court      Food & Drink Shop
# 56       Tyreso             2.0  ...                  Forest             Food Truck
#
# [6 rows x 12 columns]

# %%
Stockholm_merged.loc[Stockholm_merged['Cluster Labels'] == 3, Stockholm_merged.columns[[0] + list(range(5, Stockholm_merged.shape[1]))]]
# Out:
#       Neighborhood  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 37     Saltsjo-Boo             3.0  ...            Food Court      Food & Drink Shop
# 57  Upplands Vasby             3.0  ...            Food Truck      Food & Drink Shop
#
# [2 rows x 12 columns]

# %%
Stockholm_merged.loc[Stockholm_merged['Cluster Labels'] == 4, Stockholm_merged.columns[[0] + list(range(5, Stockholm_merged.shape[1]))]]
# Out:
#    Neighborhood  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 21     Jarfalla             4.0  ...            Food Court  Vietnamese Restaurant
#
# [1 rows x 12 columns]

# %%
Stockholm_merged.loc[Stockholm_merged['Cluster Labels'] == 5, Stockholm_merged.columns[[0] + list(range(5, Stockholm_merged.shape[1]))]]
# Out:
#    Neighborhood  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 14  Gustavsberg             5.0  ...            Food Court      Food & Drink Shop
# 20     Huddinge             5.0  ...            Food Court      Food & Drink Shop
#
# [2 rows x 12 columns]

# %%
Stockholm_merged.loc[Stockholm_merged['Cluster Labels'] == 6, Stockholm_merged.columns[[0] + list(range(5, Stockholm_merged.shape[1]))]]
# Out:
#          Neighborhood  ...  10th Most Common Venue
# 0          Akersberga  ...              Food Court
# 1                Alta  ...             Event Space
# 2              Alvsjo  ...                Gym Pool
# 3               Arsta  ...           Grocery Store
# 4         Bagarmossen  ...   Vietnamese Restaurant
# 5           Bandhagen  ...              Hobby Shop
# 7              Bromma  ...                    Farm
# 8            Danderyd  ...             Flower Shop
# 9               Ekero  ...              Food Court
# 10            Enskede  ...                Fountain
# 11       Enskede Gard  ...              Food Truck
# 12       Enskededalen  ...       Electronics Store
# 17             Handen  ...  Furniture / Home Store
# 18            Haninge  ...    Gym / Fitness Center
# 19           Hasselby  ...           Moving Target
# 22              Jarna  ...              Food Truck
# 23        Johanneshov  ...           Metro Station
# 24              Kista  ...             Salad Place
# 26            Lidingo  ...              Food Court
# 27             Marsta  ...              Restaurant
# 28              Nacka  ...             Flower Shop
# 30           Norsborg  ...  Furniture / Home Store
# 38       Saltsjobaden  ...                  Forest
# 40         Skarholmen  ...        Kebab Restaurant
# 41          Skarpnack  ...              Food Truck
# 43            Skondal  ...                Fountain
# 44         Sodertalje  ...        Department Store
# 45         Sollentuna  ...              Food Court
# 46              Solna  ...     Arts & Crafts Store
# 47             Spanga  ...             Supermarket
# 48          Stockholm  ...      Seafood Restaurant
# 49  Stockholm-Arlanda  ...               Hotel Bar
# 50   Stockholm-Globen  ...      Chinese Restaurant
# 51         Sundbyberg  ...              Food Truck
# 52               Taby  ...     Martial Arts School
# 54           Tullinge  ...              Food Court
# 55              Tumba  ...              Food Court
# 58         Vallentuna  ...          Farmers Market
# 59          Vallingby  ...                 Theater
#
# [39 rows x 12 columns]

# %%
Stockholm_merged.loc[Stockholm_merged['Cluster Labels'] == 7, Stockholm_merged.columns[[0] + list(range(5, Stockholm_merged.shape[1]))]]
# Out:
#    Neighborhood  Cluster Labels  ... 9th Most Common Venue 10th Most Common Venue
# 15    Hagersten             7.0  ...     Food & Drink Shop            Flower Shop
#
# [1 rows x 12 columns]

# %%
def getNearbyVenues1(names, latitudes, longitudes, radius=500, categoryIds=''):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
       
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            100)
            
       
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
      
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
Stockholm_food_venues = getNearbyVenues1(names=Stockholm_geo_data['Neighborhood'],
                                   latitudes=Stockholm_geo_data['Latitude'],
                                   longitudes=Stockholm_geo_data['Longitude'], radius=1000, categoryIds= '4d4b7105d754a06374d81259')
# Out:
# Akersberga
# Alta
# Alvsjo
# Arsta
# Bagarmossen
# Bandhagen
# Bro
# Bromma
# Danderyd
# Ekero
# Enskede
# Enskede Gard
# Enskededalen
# Farsta
# Gustavsberg
# Hagersten
# Hallstavik
# Handen
# Haninge
# Hasselby
# Huddinge
# Jarfalla
# Jarna
# Johanneshov
# Kista
# Kungsangen
# Lidingo
# Marsta
# Nacka
# Norrtalje
# Norsborg
# Nykvarn
# Nynashamn
# Osmo
# Rimbo
# Ronninge
# Rosersberg
# Saltsjo-Boo
# Saltsjobaden
# Sigtuna
# Skarholmen
# Skarpnack
# Skogas
# Skondal
# Sodertalje
# Sollentuna
# Solna
# Spanga
# Stockholm
# Stockholm-Arlanda
# Stockholm-Globen
# Sundbyberg
# Taby
# Tomteboda
# Tullinge
# Tumba
# Tyreso
# Upplands Vasby
# Vallentuna
# Vallingby
# Varby
# Varmdo
# Vasterhaninge
# Vaxholm

# %%
Stockholm_food_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  ...  Venue Longitude      Venue Category
# 0   Akersberga                59.4803  ...        18.297570       Grocery Store
# 1   Akersberga                59.4803  ...        18.302635    Sushi Restaurant
# 2   Akersberga                59.4803  ...        18.298988           Gastropub
# 3   Akersberga                59.4803  ...        18.299074  Light Rail Station
# 4   Akersberga                59.4803  ...        18.300780            Pharmacy
#
# [5 rows x 7 columns]

# %%
Stockholm_food_venues.shape
# Out:
# (1311, 7)

# %%
def addToMap(df, color, existingMap):
    for lat, lng, local, venue, venueCat in zip(df['Venue Latitude'], df['Venue Longitude'], df['Neighborhood'], df['Venue'], df['Venue Category']):
        label = '{} ({}) - {}'.format(venue, venueCat, local)
        label = folium.Popup(label, parse_html=True)
        folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7).add_to(existingMap)

# %%
map_Stockholm_food_venues = folium.Map(location=[latitude, longitude], zoom_start=10)
addToMap(Stockholm_food_venues, 'red', map_Stockholm_food_venues)

map_Stockholm_food_venues
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_454a45d6678e436c9f1968fd5efcf7b7%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_454a45d6678e436c9f1968fd5efcf7b7%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_454a45d6678e436c9f1968fd5efcf7b7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_454a45d6678e436c9f1968fd5efcf7b7%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B59.3251172%2C%2018.0710935%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_77cf209c0a284641a12bee737b5ed09a%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%2 ...

# %%
Stockholm_grouped_1=  Stockholm_food_venues.groupby('Neighborhood').count()
Stockholm_grouped_1.head()
# Out:
#               Neighborhood Latitude  ...  Venue Category
# Neighborhood                         ...
# Akersberga                       12  ...              12
# Alta                              9  ...               9
# Alvsjo                           26  ...              26
# Arsta                            37  ...              37
# Bagarmossen                      21  ...              21
#
# [5 rows x 6 columns]

# %%
Stockholm_grouped_1.shape
# Out:
# (64, 6)

# %%
Data_1= pd.DataFrame(data=Stockholm_grouped_1, columns=['Venue'] )
Data_1
# Out:
#                Venue
# Neighborhood
# Akersberga        12
# Alta               9
# Alvsjo            26
# Arsta             37
# Bagarmossen       21
# ...              ...
# Vallingby         33
# Varby              9
# Varmdo             3
# Vasterhaninge     11
# Vaxholm           12
#
# [64 rows x 1 columns]

# %%
Stockholm= pd.merge(Stockholm_geo_data , Data_1, on='Neighborhood')

# %%
Stockholm
# Out:
#      Neighborhood  ...  Venue
# 0      Akersberga  ...     12
# 1            Alta  ...      9
# 2          Alvsjo  ...     26
# 3           Arsta  ...     37
# 4     Bagarmossen  ...     21
# ..            ...  ...    ...
# 59      Vallingby  ...     33
# 60          Varby  ...      9
# 61         Varmdo  ...      3
# 62  Vasterhaninge  ...     11
# 63        Vaxholm  ...     12
#
# [64 rows x 6 columns]

# %%
Stockholm_1=pd.DataFrame(data= Stockholm, columns= ['Neighborhood', 'Density'])
Stockholm_1
# Out:
#      Neighborhood  Density
# 0      Akersberga      NaN
# 1            Alta      NaN
# 2          Alvsjo      NaN
# 3           Arsta      NaN
# 4     Bagarmossen      NaN
# ..            ...      ...
# 59      Vallingby      NaN
# 60          Varby      NaN
# 61         Varmdo      NaN
# 62  Vasterhaninge      NaN
# 63        Vaxholm      NaN
#
# [64 rows x 2 columns]

# %%
Stockholm_1['Density']= Stockholm['Venue']/Stockholm['Population ']

# %%
Stockholm_1.head()
# Out:
#   Neighborhood   Density
# 0   Akersberga  0.000428
# 1         Alta  0.000901
# 2       Alvsjo  0.016993
# 3        Arsta  0.002201
# 4  Bagarmossen  0.001924

# %%
Stockholm_1=Stockholm_1.sort_values(by= ['Density'])
pd.set_option("max_rows", None)
Stockholm_1
# Out:
#          Neighborhood   Density
# 20           Huddinge  0.000018
# 28              Nacka  0.000038
# 45         Sollentuna  0.000041
# 61             Varmdo  0.000066
# 56             Tyreso  0.000082
# 10            Enskede  0.000093
# 48          Stockholm  0.000102
# 37        Saltsjo-Boo  0.000125
# 21           Jarfalla  0.000197
# 44         Sodertalje  0.000230
# 58         Vallentuna  0.000234
# 29          Norrtalje  0.000236
# 9               Ekero  0.000243
# 18            Haninge  0.000268
# 57     Upplands Vasby  0.000275
# 8            Danderyd  0.000306
# 55              Tumba  0.000317
# 51         Sundbyberg  0.000323
# 15          Hagersten  0.000324
# 13             Farsta  0.000362
# 39            Sigtuna  0.000365
# 54           Tullinge  0.000375
# 26            Lidingo  0.000396
# 59          Vallingby  0.000400
# 0          Akersberga  0.000428
# 14        Gustavsberg  0.000441
# 19           Hasselby  0.000479
# 25         Kungsangen  0.000533
# 31            Nykvarn  0.000624
# 27             Marsta  0.000629
# 52               Taby  0.000633
# 47             Spanga  0.000640
# 62      Vasterhaninge  0.000727
# 42             Skogas  0.000761
# 60              Varby  0.000839
# 6                 Bro  0.000851
# 16         Hallstavik  0.000895
# 1                Alta  0.000901
# 32          Nynashamn  0.000903
# 22              Jarna  0.000941
# 38       Saltsjobaden  0.000948
# 46              Solna  0.000948
# 17             Handen  0.000994
# 63            Vaxholm  0.001011
# 30           Norsborg  0.001176
# 40         Skarholmen  0.001485
# 34              Rimbo  0.001512
# 24              Kista  0.001536
# 41          Skarpnack  0.001552
# 35           Ronninge  0.001627
# 33               Osmo  0.001790
# 4         Bagarmossen  0.001924
# 43            Skondal  0.002013
# 3               Arsta  0.002201
# 5           Bandhagen  0.002304
# 7              Bromma  0.003889
# 36         Rosersberg  0.004788
# 23        Johanneshov  0.008003
# 12       Enskededalen  0.010652
# 11       Enskede Gard  0.010834
# 2              Alvsjo  0.016993
# 49  Stockholm-Arlanda       inf
# 50   Stockholm-Globen       inf
# 53          Tomteboda       inf

# %% [markdown]
# #*RESULTS*
# As showen above, there is a huge disparity in the supply levels across Stockholm. Some neighborhoods might benfite immidiatly from opining any food venues in it.  Huddinge,	Nacka and Sollentuna rank as least coverd neighborhoods. Further investigation will help in understand the need of each neighborhood; the type of food venues might differ according to the need of the respective neighborhood.
